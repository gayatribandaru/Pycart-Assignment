# %% [markdown]
# <a href="https://colab.research.google.com/github/gayatribandaru/Pycart-Assignment/blob/main/pycaret.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.4/484.4 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 7.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 21.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 12.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.5/17.5 MB 77.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 68.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 72.2 MB/s eta 0:00:00
# ...

# %%
import os
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('/content/AirlineDataset.csv')

# Show the first few rows to make sure it's loaded correctly
print(df.head())
# Out:
#    Passenger ID First Name Last Name  Gender  Age Nationality  \
# 0         10856     Edithe    Leggis  Female   62       Japan
# 1         43872     Elwood      Catt    Male   62   Nicaragua
# 2         42633      Darby   Felgate    Male   67      Russia
# 3         78493   Dominica      Pyle  Female   71       China
# 4         82072        Bay   Pencost    Male   21       China
#
#                 Airport Name Airport Country Code   Country Name  \
# 0           Coldfoot Airport                   US  United States
# 1          Kugluktuk Airport                   CA         Canada
# 2     Grenoble-Isère Airport                   FR         France
# 3  Ottawa / Gatineau Airport                   CA         Canada
# 4            Gillespie Field                   US  United States
#
#   Airport Continent     Continents Departure Date Arrival Airport  \
# 0               NAM  North America      6/28/2022             CXF
# ...

# %%
from pycaret.classification import setup

# Automatic preprocessing and environment setup
clf1 = setup(data = df, target = 'Gender')
# Out:
# <style type="text/css">
# #T_653df_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_653df" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_653df_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_653df_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_653df_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_653df_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_653df_row0_col1" class="data row0 col1" >3735</td>
#     </tr>
#     <tr>
#       <th id="T_653df_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_653df_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_653df_row1_col1" class="data row1 col1" >Gender</td>
#     </tr>
#     <tr>
#       <th id="T_653df_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
from pycaret.classification import compare_models

# This will compare all models and return the best performing one
best_model = compare_models()
# Out:
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         00:25:13
# Status                    Fitting 10 Folds
# Estimator  Light Gradient Boosting Machine
# <style type="text/css">
# #T_26004 th {
#   text-align: left;
# }
# ...

# %%
from pycaret.classification import tune_model

# Fine-tune the best model
tuned_model = tune_model(best_model)
# Out:
# <style type="text/css">
# #T_5aa64_row10_col0, #T_5aa64_row10_col1, #T_5aa64_row10_col2, #T_5aa64_row10_col3, #T_5aa64_row10_col4, #T_5aa64_row10_col5, #T_5aa64_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_5aa64" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5aa64_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_5aa64_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_5aa64_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_5aa64_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_5aa64_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_5aa64_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_5aa64_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
from pycaret.classification import evaluate_model

# Evaluate the tuned model
evaluate_model(tuned_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
from pycaret.classification import predict_model

# Make predictions on new data
predictions = predict_model(tuned_model, data = df)
# Out:
# <style type="text/css">
# </style>
# <table id="T_942d4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_942d4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_942d4_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_942d4_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_942d4_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_942d4_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_942d4_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_942d4_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_942d4_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_942d4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_942d4_row0_col0" class="data row0 col0" >Ridge Classifier</td>
# ...
